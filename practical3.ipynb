# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import numpy as np

# Load dataset
data = pd.read_csv('./Diwali Sales Data.csv')

# Prepare data for linear regression
X = data[['Age', 'Orders']].values
y = data['Amount'].values

# Handle missing values
X = np.nan_to_num(X)
y = np.nan_to_num(y)

# Create linear regression object
reg = LinearRegression().fit(X, y)

# Make predictions
predictions = reg.predict(X)
print(predictions)
# Out:
# Running cells with 'env (Python 3.12.4)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'd:/ML/env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np

# Load dataset
data = pd.read_csv('/c:/Users/thura/OneDrive/Desktop/ML/Diwali Sales Data.csv')

# Prepare data for logistic regression
X = data[['Age', 'Orders']].values
y = data['Marital_Status'].values

# Handle missing values
X = np.nan_to_num(X)
y = np.nan_to_num(y)

# Create logistic regression object
clf = LogisticRegression().fit(X, y)

# Make predictions
predictions = clf.predict(X)
print(predictions)
