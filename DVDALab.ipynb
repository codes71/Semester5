# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/tested.csv')

# %%
# df = dataFrame View the data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#unique values
df['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
#checking Duplicate values
df.nunique()
# Out:
# PassengerId    418
# Survived         2
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
#find null values or check for missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Replace
df.replace(np.nan,'0',inplace=True)

# %%
df.dtypes
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# Sex            object
# Age            object
# SibSp           int64
# Parch           int64
# Ticket         object
# Fare           object
# Cabin          object
# Embarked       object
# dtype: object

# %%
df[df['Pclass']==1].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 11          903         0       1
# 12          904         1       1
# 14          906         1       1
# 20          912         0       1
# 22          914         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                             Rothschild, Mr. Martin    male  55.0      1
# 22               Flegenheim, Mrs. Alfred (Antoinette)  female     0      0
#
#     Parch       Ticket     Fare Cabin Embarked
# 11      0          694     26.0     0        S
# 12      0        21228  82.2667   B45        S
# 14      0  W.E.P. 5734   61.175   E31        S
# 20      0     PC 17603     59.4     0        C
# 22      0     PC 17598  31.6833     0        S

# %%
df[df['PassengerId']==894]
# Out:
#    PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 2          894         0       2  Myles, Mr. Thomas Francis  male  62.0
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked
# 2      0      0  240276  9.6875     0        Q

# %%
df = pd.read_csv('datasets/winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
qualityCount=df['quality'].value_counts()
qualityCount
# Out:
# quality
# 5    680
# 6    637
# 7    199
# 4     52
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.bar(qualityCount.index,qualityCount,color = 'Maroon')
plt.title('Count Plot of Quality of Wine')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.show()

# %%
#density Plot
sns.set_style('darkgrid')

# %%
numericalColumn = df.select_dtypes(include=['int64','float64']).columns
numericalColumn
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#kde ဆိုတာ အပေါ်မှာ ပေါ်နေတဲ့ မျဥ်းေကြာင်းကိုေပြာတာဖြစ် 
plt.figure(figsize=(14,len(numericalColumn)*5))
for idx , feature in enumerate(numericalColumn,1):
    plt.subplot(len(numericalColumn),2,idx)
    sns.histplot(df[feature],kde=True)
    plt.title(f"{feature} | Skewness:{round (df[feature].skew(),2)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #kde ဆိုတာ အပေါ်မှာ ပေါ်နေတဲ့ မျဥ်းေကြာင်းကိုေပြာတာဖြစ်
# ----> 2 plt.figure(figsize=(14,len(numericalColumn)*5))
#       3 for idx , feature in enumerate(numericalColumn,1):
#       4     plt.subplot(len(numericalColumn),2,idx)
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(14,len(numericalColumn)*5))
for idx , feature in enumerate(numericalColumn,1):
    plt.subplot(len(numericalColumn),2,idx)
    sns.histplot(df[feature],kde=True)
    plt.title(f"{feature} | Skewness:{round (df[feature].skew(),2)}")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='quality',y='alcohol', data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
import warnings as wr
wr.filterwarnings('ignore')

# %%
sns.swarmplot(x='quality',y='alcohol',data=df,palette='viridis')
plt.title("SwarmPlot for Quality and Alcohol")
plt.xlabel("Quality")
plt.ylabel("Alcohol")
plt.show()
